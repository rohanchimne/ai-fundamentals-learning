# %%
from openai import OpenAI
# import os
# from dotenv import load_dotenv

# load_dotenv()

client = OpenAI()

response = client.responses.create(
    model="gpt-3.5-turbo",
    input= "what is the capital of France?"
)

print(response.output_text)
# Out:
# The capital of France is Paris.

# %%
client = OpenAI()

response = client.responses.create(
    model="gpt-3.5-turbo",
    input= "What is UT UT AUSTIN?"
)

print(response.output_text)
# Out:
# UT Austin stands for The University of Texas at Austin. It is a public research university located in Austin, Texas, and is one of the largest and most prestigious universities in the United States. UT Austin offers a wide range of undergraduate and graduate programs across various disciplines and is known for its strong academic reputation and research contributions.
